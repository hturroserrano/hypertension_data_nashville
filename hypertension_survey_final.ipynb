# %% [markdown]
# <a href="https://colab.research.google.com/github/hturroserrano/hypertension_data_nashville/blob/main/hypertension_survey_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import tree
import pydotplus
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
surveyurl = 'https://raw.githubusercontent.com/CDavisBelmont/SurveyData/main/health_surv_ques.csv'

# %%
df = pd.read_csv(surveyurl)

# %%
hispanic_hyp = df.columns[48]

# %%
hispanic_df = df[df[hispanic_hyp]== 1]

# %%
white_hyp = df.columns[42]

# %%
white_df = df[df[white_hyp]== 1]

# %%
black_hyp = df.columns[41]

# %%
black_df = df[df[black_hyp]== 1]

# %%
asian_hyp = df.columns[40]

# %%
asian_df = df[df[asian_hyp]== 1]

# %%
pacific_islander_hyp = df.columns[39]

# %%
pacific_islander_df = df[df[pacific_islander_hyp]== 1]

# %%
native_american_hyp = df.columns[38]

# %%
native_american_df = df[df[native_american_hyp]== 1]

# %%
other_race_hyp = df.columns[37]

# %%
other_race_df = df[df[other_race_hyp]== 1]

# %%
transportation_to_healthy_foods = df.columns[154]

# %%
his_transportation_to_healthy_foods = hispanic_df.columns[154]

# %%
white_transportation_to_healthy_foods = white_df.columns[154]

# %%
black_transportation_to_healthy_foods = black_df.columns[154]

# %%
asian_transportation_to_healthy_foods = asian_df.columns[154]

# %%
pi_transportation_to_healthy_foods = pacific_islander_df.columns[154]

# %%
na_transportation_to_healthy_foods = native_american_df.columns[154]

# %%
other_transportation_to_healthy_foods = other_race_df.columns[154]

# %%
difficult_transportation_doctor = df.columns[59]

# %%
his_difficult_transportation_doctor = hispanic_df.columns[59]

# %%
white_difficult_transportation_doctor = white_df.columns[59]

# %%
black_difficult_transportation_doctor = black_df.columns[59]

# %%
asian_difficult_transportation_doctor = asian_df.columns[59]

# %%
pi_difficult_transportation_doctor = pacific_islander_df.columns[59]

# %%
na_difficult_transportation_doctor = native_american_df.columns[59]

# %%
other_difficult_transportation_doctor = other_race_df.columns[59]

# %%
transportation_to_healthy_foods_list = df[transportation_to_healthy_foods].unique()
a_transportation_to_healthy_foods_list = np.delete(transportation_to_healthy_foods_list, 1)

# %%
his_transportation_to_healthy_foods_list = hispanic_df[transportation_to_healthy_foods].unique()
a_his_transportation_to_healthy_foods_list = np.delete(transportation_to_healthy_foods_list, 1)

# %%
white_transportation_to_healthy_foods_list = white_df[transportation_to_healthy_foods].unique()
a_white_transportation_to_healthy_foods_list = np.delete(transportation_to_healthy_foods_list, 1)

# %%
black_transportation_to_healthy_foods_list = black_df[transportation_to_healthy_foods].unique()
a_black_transportation_to_healthy_foods_list = np.delete(transportation_to_healthy_foods_list, 1)

# %%
asian_transportation_to_healthy_foods_list = asian_df[transportation_to_healthy_foods].unique()
a_asian_transportation_to_healthy_foods_list = np.delete(transportation_to_healthy_foods_list, 1)

# %%
pi_transportation_to_healthy_foods_list = pacific_islander_df[transportation_to_healthy_foods].unique()
a_pi_transportation_to_healthy_foods_list = np.delete(transportation_to_healthy_foods_list, 1)

# %%
na_transportation_to_healthy_foods_list = native_american_df[transportation_to_healthy_foods].unique()
a_na_transportation_to_healthy_foods_list = np.delete(transportation_to_healthy_foods_list, 1)

# %%
other_transportation_to_healthy_foods_list = other_race_df[transportation_to_healthy_foods].unique()
a_other_transportation_to_healthy_foods_list = np.delete(transportation_to_healthy_foods_list, 1)

# %%
survey_healthy_food_transportation_counts = np.zeros(len(transportation_to_healthy_foods_list))
for i, foodtransportation in enumerate(transportation_to_healthy_foods_list):
  survey_healthy_food_transportation_counts[i] = len(df[df[transportation_to_healthy_foods]==foodtransportation])

# %%
survey_healthy_food_transportation_counts
# Out:
# array([1424.,    0.,  238.,   86.,   18.,   26.])

# %%
his_survey_healthy_food_transportation_counts = np.zeros(len(a_his_transportation_to_healthy_foods_list))
for i, foodtransportation in enumerate(a_his_transportation_to_healthy_foods_list):
  his_survey_healthy_food_transportation_counts[i] = len(hispanic_df[hispanic_df[transportation_to_healthy_foods]==foodtransportation])

# %%
his_survey_healthy_food_transportation_counts
# Out:
# array([84., 18.,  7.,  2.,  0.])

# %%
white_survey_healthy_food_transportation_counts = np.zeros(len(a_white_transportation_to_healthy_foods_list))
for i, foodtransportation in enumerate(a_white_transportation_to_healthy_foods_list):
  white_survey_healthy_food_transportation_counts[i] = len(white_df[white_df[transportation_to_healthy_foods]==foodtransportation])

# %%
white_survey_healthy_food_transportation_counts
# Out:
# array([1011.,  141.,   37.,   11.,   12.])

# %%
black_survey_healthy_food_transportation_counts = np.zeros(len(a_black_transportation_to_healthy_foods_list))
for i, foodtransportation in enumerate(a_black_transportation_to_healthy_foods_list):
  black_survey_healthy_food_transportation_counts[i] = len(black_df[black_df[transportation_to_healthy_foods]==foodtransportation])

# %%
black_survey_healthy_food_transportation_counts
# Out:
# array([305.,  63.,  36.,   4.,  13.])

# %%
asian_survey_healthy_food_transportation_counts = np.zeros(len(a_asian_transportation_to_healthy_foods_list))
for i, foodtransportation in enumerate(a_asian_transportation_to_healthy_foods_list):
  asian_survey_healthy_food_transportation_counts[i] = len(asian_df[asian_df[transportation_to_healthy_foods]==foodtransportation])

# %%
asian_survey_healthy_food_transportation_counts
# Out:
# array([29., 14.,  3.,  0.,  1.])

# %%
pi_survey_healthy_food_transportation_counts = np.zeros(len(a_pi_transportation_to_healthy_foods_list))
for i, foodtransportation in enumerate(a_pi_transportation_to_healthy_foods_list):
  pi_survey_healthy_food_transportation_counts[i] = len(pacific_islander_df[pacific_islander_df[transportation_to_healthy_foods]==foodtransportation])

# %%
pi_survey_healthy_food_transportation_counts
# Out:
# array([5., 1., 1., 0., 0.])

# %%
na_survey_healthy_food_transportation_counts = np.zeros(len(a_na_transportation_to_healthy_foods_list))
for i, foodtransportation in enumerate(a_na_transportation_to_healthy_foods_list):
  na_survey_healthy_food_transportation_counts[i] = len(native_american_df[native_american_df[transportation_to_healthy_foods]==foodtransportation])

# %%
na_survey_healthy_food_transportation_counts
# Out:
# array([14.,  3.,  4.,  1.,  0.])

# %%
other_survey_healthy_food_transportation_counts = np.zeros(len(a_other_transportation_to_healthy_foods_list))
for i, foodtransportation in enumerate(a_other_transportation_to_healthy_foods_list):
  other_survey_healthy_food_transportation_counts[i] = len(other_race_df[other_race_df[transportation_to_healthy_foods]==foodtransportation])

# %%
other_survey_healthy_food_transportation_counts
# Out:
# array([46., 11.,  6.,  2.,  0.])

# %%
###################################

# %%
hyp_difficult_transportation_doctor_list = df[difficult_transportation_doctor].unique()
a_difficult_transportation_doctor_list = np.delete(hyp_difficult_transportation_doctor_list, 0)

# %%
his_difficult_transportation_doctor_list = hispanic_df[difficult_transportation_doctor].unique()
a_his_difficult_transportation_doctor_list = np.delete(hyp_difficult_transportation_doctor_list, 0)

# %%
white_difficult_transportation_doctor_list = white_df[difficult_transportation_doctor].unique()
a_white_difficult_transportation_doctor_list = np.delete(hyp_difficult_transportation_doctor_list, 0)

# %%
black_difficult_transportation_doctor_list = black_df[difficult_transportation_doctor].unique()
a_black_difficult_transportation_doctor_list = np.delete(hyp_difficult_transportation_doctor_list, 0)

# %%
asian_difficult_transportation_doctor_list = asian_df[difficult_transportation_doctor].unique()
a_asian_difficult_transportation_doctor_list = np.delete(hyp_difficult_transportation_doctor_list, 0)

# %%
pi_difficult_transportation_doctor_list = pacific_islander_df[difficult_transportation_doctor].unique()
a_pi_difficult_transportation_doctor_list = np.delete(hyp_difficult_transportation_doctor_list, 0)

# %%
na_difficult_transportation_doctor_list = native_american_df[difficult_transportation_doctor].unique()
a_na_difficult_transportation_doctor_list = np.delete(hyp_difficult_transportation_doctor_list, 0)

# %%
other_difficult_transportation_doctor_list = other_race_df[difficult_transportation_doctor].unique()
a_other_difficult_transportation_doctor_list = np.delete(hyp_difficult_transportation_doctor_list, 0)

# %%
survey_difficult_transportation_doctor_counts = np.zeros(len(hyp_difficult_transportation_doctor_list))
for i, doctortransportation in enumerate(hyp_difficult_transportation_doctor_list):
  survey_difficult_transportation_doctor_counts[i] = len(df[df[difficult_transportation_doctor]==doctortransportation])

# %%
completed_doctor_counts = np.delete(survey_difficult_transportation_doctor_counts, 0)

# %%
completed_doctor_counts
# Out:
# array([ 216., 1433.,   20.,   83.,   14.])

# %%
his_survey_difficult_transportation_doctor_counts = np.zeros(len(a_his_difficult_transportation_doctor_list))
for i, doctortransportation in enumerate(a_his_difficult_transportation_doctor_list):
  his_survey_difficult_transportation_doctor_counts[i] = len(hispanic_df[hispanic_df[difficult_transportation_doctor]==doctortransportation])

# %%
his_survey_difficult_transportation_doctor_counts
# Out:
# array([27., 82.,  1.,  4.,  2.])

# %%
white_survey_difficult_transportation_doctor_counts = np.zeros(len(a_white_difficult_transportation_doctor_list))
for i, doctortransportation in enumerate(a_white_difficult_transportation_doctor_list):
  white_survey_difficult_transportation_doctor_counts[i] = len(white_df[white_df[difficult_transportation_doctor]==doctortransportation])

# %%
white_survey_difficult_transportation_doctor_counts
# Out:
# array([ 120., 1033.,    6.,   50.,    6.])

# %%
black_survey_difficult_transportation_doctor_counts = np.zeros(len(a_black_difficult_transportation_doctor_list))
for i, doctortransportation in enumerate(a_black_difficult_transportation_doctor_list):
  black_survey_difficult_transportation_doctor_counts[i] = len(black_df[black_df[difficult_transportation_doctor]==doctortransportation])

# %%
asian_survey_difficult_transportation_doctor_counts = np.zeros(len(a_asian_difficult_transportation_doctor_list))
for i, doctortransportation in enumerate(a_asian_difficult_transportation_doctor_list):
  asian_survey_difficult_transportation_doctor_counts[i] = len(asian_df[asian_df[difficult_transportation_doctor]==doctortransportation])

# %%
pi_survey_difficult_transportation_doctor_counts = np.zeros(len(a_pi_difficult_transportation_doctor_list))
for i, doctortransportation in enumerate(a_pi_difficult_transportation_doctor_list):
  pi_survey_difficult_transportation_doctor_counts[i] = len(pacific_islander_df[pacific_islander_df[difficult_transportation_doctor]==doctortransportation])

# %%
na_survey_difficult_transportation_doctor_counts = np.zeros(len(a_na_difficult_transportation_doctor_list))
for i, doctortransportation in enumerate(a_na_difficult_transportation_doctor_list):
  na_survey_difficult_transportation_doctor_counts[i] = len(native_american_df[native_american_df[difficult_transportation_doctor]==doctortransportation])

# %%
other_survey_difficult_transportation_doctor_counts = np.zeros(len(a_other_difficult_transportation_doctor_list))
for i, doctortransportation in enumerate(a_other_difficult_transportation_doctor_list):
  other_survey_difficult_transportation_doctor_counts[i] = len(other_race_df[other_race_df[difficult_transportation_doctor]==doctortransportation])

# %%
###################################

# %%
fig,ax=plt.subplots(1,1, figsize=(16,10))
plt.bar(a_difficult_transportation_doctor_list,completed_doctor_counts)
plt.ylabel("# of People", fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title("Difficulty For People To Get Transportation To Get Medical Help (Hypertension Survey)", fontsize = 20)
plt.text(.6, 1400, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 1300, "2 = Very Difficult",fontsize = 15)
plt.text(.6,1200, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,1100, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,1000, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 1000, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_his_difficult_transportation_doctor_list,his_survey_difficult_transportation_doctor_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get A Ride To A Doctor or Medical Help (Hispanic) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 80, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 70, "2 = Very Difficult",fontsize = 15)
plt.text(.6,60, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,50, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,40, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 40, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_white_difficult_transportation_doctor_list,white_survey_difficult_transportation_doctor_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get A Ride To A Doctor or Medical Help (White) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 1000, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 900, "2 = Very Difficult",fontsize = 15)
plt.text(.6,800, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,700, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,600, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 600, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_black_difficult_transportation_doctor_list,black_survey_difficult_transportation_doctor_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get A Ride To A Doctor or Medical Help (Black) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 300, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 275, "2 = Very Difficult",fontsize = 15)
plt.text(.6,250, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,225, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,200, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 200, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_asian_difficult_transportation_doctor_list,asian_survey_difficult_transportation_doctor_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get A Ride To A Doctor or Medical Help (Asian) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 25, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 22.5, "2 = Very Difficult",fontsize = 15)
plt.text(.6,20, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,17.5, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,15, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 15, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_pi_difficult_transportation_doctor_list,pi_survey_difficult_transportation_doctor_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get A Ride To A Doctor or Medical Help (Pacific Islander) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 5.5, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 5, "2 = Very Difficult",fontsize = 15)
plt.text(.6,4.5, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,4, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,3.5, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 3.5, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_na_difficult_transportation_doctor_list,na_survey_difficult_transportation_doctor_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get A Ride To A Doctor or Medical Help (Native American) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 11, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 10, "2 = Very Difficult",fontsize = 15)
plt.text(.6,9, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,8, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,7, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 7, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_other_difficult_transportation_doctor_list,other_survey_difficult_transportation_doctor_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get A Ride To A Doctor or Medical Help (Other) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 40, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 35, "2 = Very Difficult",fontsize = 15)
plt.text(.6,30, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,25, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,20, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 20, '5 = Not At All Difficult')

# %%
###################################

# %%
fig,ax=plt.subplots(1,1, figsize=(16,10))
plt.bar(transportation_to_healthy_foods_list,survey_healthy_food_transportation_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Have Access To Healthy Foods Due To Transportation (Hypertension Survey)", fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.text(.6, 1400, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 1300, "2 = Very Difficult",fontsize = 15)
plt.text(.6,1200, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,1100, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,1000, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 1000, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_his_transportation_to_healthy_foods_list,his_survey_healthy_food_transportation_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get Healthy Foods (Hispanic) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 80, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 70, "2 = Very Difficult",fontsize = 15)
plt.text(.6,60, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,50, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,40, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 40, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_white_transportation_to_healthy_foods_list,white_survey_healthy_food_transportation_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get Healthy Foods (White) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 1000, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 900, "2 = Very Difficult",fontsize = 15)
plt.text(.6,800, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,700, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,600, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 600, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_black_transportation_to_healthy_foods_list,black_survey_healthy_food_transportation_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get Healthy Foods (Black) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 300, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 275, "2 = Very Difficult",fontsize = 15)
plt.text(.6,250, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,225, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,200, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 200, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_asian_transportation_to_healthy_foods_list,asian_survey_healthy_food_transportation_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get Healthy Foods (Asian) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 28, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 25, "2 = Very Difficult",fontsize = 15)
plt.text(.6,22, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,19, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,16, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 16, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_pi_transportation_to_healthy_foods_list,pi_survey_healthy_food_transportation_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get Healthy Foods (Pacific Islander) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 4.8, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 4.3, "2 = Very Difficult",fontsize = 15)
plt.text(.6,3.8, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,3.3, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,2.8, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 2.8, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_na_transportation_to_healthy_foods_list,na_survey_healthy_food_transportation_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get Healthy Foods (Native American) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 14, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 12.5, "2 = Very Difficult",fontsize = 15)
plt.text(.6,11, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,9.5, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,8, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 8, '5 = Not At All Difficult')

# %%
fig,ax=plt.subplots(1,1, figsize=(14,8))
plt.bar(a_other_transportation_to_healthy_foods_list,other_survey_healthy_food_transportation_counts)
plt.ylabel("# of People", fontsize = 15)
plt.title("Difficulty For People To Get Healthy Foods (Other Race) (Hypertension Survey)", fontsize = 20)
plt.text(.6, 45, "1 = Extremely Difficult",fontsize = 15)
plt.text(.6, 40, "2 = Very Difficult",fontsize = 15)
plt.text(.6,35, "3 = Somewhat Difficult", fontsize = 15)
plt.text(.6,30, "4 = Not Very Difficult", fontsize = 15)
plt.text(.6,25, "5 = Not At All Difficult", fontsize = 15)
# Out:
# Text(0.6, 25, '5 = Not At All Difficult')
