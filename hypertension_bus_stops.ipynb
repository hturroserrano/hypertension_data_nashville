# %% [markdown]
# <a href="https://colab.research.google.com/github/hturroserrano/hypertension_data_nashville/blob/main/hypertension_bus_stops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
df = pd.read_pickle("https://github.com/CDavisBelmont/SurveyData/raw/main/bus_stops.pkl")

# %%
df
# Out:
#       Stop ID Stop Abbreviation                             Stop Name  \
# 4        4133           GRWHIWN       GREEN LN & WHITES CREEK PIKE WB
# 5        4083          Z9AEDGSN         _ 9TH AVE S & EDGEHILL AVE SB
# 6        5066          MXODONEL        DONELSON/DELL STATION OUTBOUND
# 7          94          17ADORSN            17TH AVE S & DOROTHY PL SB
# 8        3219          COC14AWN              COCKRILL ST & 14TH AVE N
# ...       ...               ...                                   ...
# 2572     5320          EZECONWN         EZELL PIKE CONVENIENCE CTR WB
# 2573     5166          JEF6AVWM             JEFFERSON ST & 6TH AVE WB
# 2574     4698          NEEJAPEF     NEELY'S BEND RD & JASPERSON DR EB
# 2576     4714          OLDFORWN  OLD HICKORY BLVD & FOREST PARK RD WB
# 2577     1940          THOEIREF            THOMPSON LN & EAST IRIS DR
#
#       Shelter?  Bench? Route Numbers                Route Name  \
# ...
